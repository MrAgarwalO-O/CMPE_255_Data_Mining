# %%
# !pip install pycaret

# %%
import pandas as pd

url = '/content/car_evaluation.csv'
data = pd.read_csv(url)

data
# Out:
#       vhigh vhigh.1      2   2.1  small   low  unacc
# 0     vhigh   vhigh      2     2  small   med  unacc
# 1     vhigh   vhigh      2     2  small  high  unacc
# 2     vhigh   vhigh      2     2    med   low  unacc
# 3     vhigh   vhigh      2     2    med   med  unacc
# 4     vhigh   vhigh      2     2    med  high  unacc
# ...     ...     ...    ...   ...    ...   ...    ...
# 1722    low     low  5more  more    med   med   good
# 1723    low     low  5more  more    med  high  vgood
# 1724    low     low  5more  more    big   low  unacc
# 1725    low     low  5more  more    big   med   good
# 1726    low     low  5more  more    big  high  vgood
#
# [1727 rows x 7 columns]

# %%
col_names = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'dec']
data.columns=col_names
data
# Out:
#      buying  maint  doors persons lug_boot safety    dec
# 0     vhigh  vhigh      2       2    small    med  unacc
# 1     vhigh  vhigh      2       2    small   high  unacc
# 2     vhigh  vhigh      2       2      med    low  unacc
# 3     vhigh  vhigh      2       2      med    med  unacc
# 4     vhigh  vhigh      2       2      med   high  unacc
# ...     ...    ...    ...     ...      ...    ...    ...
# 1722    low    low  5more    more      med    med   good
# 1723    low    low  5more    more      med   high  vgood
# 1724    low    low  5more    more      big    low  unacc
# 1725    low    low  5more    more      big    med   good
# 1726    low    low  5more    more      big   high  vgood
#
# [1727 rows x 7 columns]

# %%
from pycaret.classification import*
s = setup(data,target="dec", use_gpu=True)
# Out:
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# <style type="text/css">
# #T_98272_row9_col1, #T_98272_row18_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_98272" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98272_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_98272_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98272_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98272_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_98272_row0_col1" class="data row0 col1" >6921</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_98272_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_98272_row1_col1" class="data row1 col1" >dec</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_98272_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_98272_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_98272_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_98272_row3_col1" class="data row3 col1" >acc: 0, good: 1, unacc: 2, vgood: 3</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_98272_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_98272_row4_col1" class="data row4 col1" >(1727, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_98272_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_98272_row5_col1" class="data row5 col1" >(1727, 22)</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_98272_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_98272_row6_col1" class="data row6 col1" >(1208, 22)</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_98272_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_98272_row7_col1" class="data row7 col1" >(519, 22)</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_98272_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_98272_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_98272_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_98272_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_98272_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_98272_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_98272_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_98272_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_98272_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_98272_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_98272_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_98272_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_98272_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_98272_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_98272_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_98272_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_98272_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_98272_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_98272_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_98272_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_98272_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_98272_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_98272_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_98272_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_98272_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_98272_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_98272_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_98272_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_98272_row21_col1" class="data row21 col1" >6ee3</td>
#     </tr>
#   </tbody>
# </table>
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_09574 th {
#   text-align: left;
# }
# #T_09574_row0_col0, #T_09574_row1_col0, #T_09574_row1_col1, #T_09574_row1_col2, #T_09574_row1_col3, #T_09574_row1_col4, #T_09574_row1_col5, #T_09574_row1_col6, #T_09574_row1_col7, #T_09574_row2_col0, #T_09574_row2_col1, #T_09574_row2_col2, #T_09574_row2_col3, #T_09574_row2_col4, #T_09574_row2_col5, #T_09574_row2_col6, #T_09574_row2_col7, #T_09574_row3_col0, #T_09574_row3_col1, #T_09574_row3_col2, #T_09574_row3_col3, #T_09574_row3_col4, #T_09574_row3_col5, #T_09574_row3_col6, #T_09574_row3_col7, #T_09574_row4_col0, #T_09574_row4_col1, #T_09574_row4_col2, #T_09574_row4_col3, #T_09574_row4_col4, #T_09574_row4_col5, #T_09574_row4_col6, #T_09574_row4_col7, #T_09574_row5_col0, #T_09574_row5_col1, #T_09574_row5_col2, #T_09574_row5_col3, #T_09574_row5_col4, #T_09574_row5_col5, #T_09574_row5_col6, #T_09574_row5_col7, #T_09574_row6_col0, #T_09574_row6_col1, #T_09574_row6_col2, #T_09574_row6_col3, #T_09574_row6_col4, #T_09574_row6_col5, #T_09574_row6_col6, #T_09574_row6_col7, #T_09574_row7_col0, #T_09574_row7_col1, #T_09574_row7_col2, #T_09574_row7_col3, #T_09574_row7_col4, #T_09574_row7_col5, #T_09574_row7_col6, #T_09574_row7_col7, #T_09574_row8_col0, #T_09574_row8_col1, #T_09574_row8_col2, #T_09574_row8_col3, #T_09574_row8_col4, #T_09574_row8_col5, #T_09574_row8_col6, #T_09574_row8_col7, #T_09574_row9_col0, #T_09574_row9_col1, #T_09574_row9_col2, #T_09574_row9_col3, #T_09574_row9_col4, #T_09574_row9_col5, #T_09574_row9_col6, #T_09574_row9_col7, #T_09574_row10_col0, #T_09574_row10_col1, #T_09574_row10_col2, #T_09574_row10_col3, #T_09574_row10_col4, #T_09574_row10_col5, #T_09574_row10_col6, #T_09574_row10_col7, #T_09574_row11_col0, #T_09574_row11_col1, #T_09574_row11_col2, #T_09574_row11_col3, #T_09574_row11_col4, #T_09574_row11_col5, #T_09574_row11_col6, #T_09574_row11_col7, #T_09574_row12_col0, #T_09574_row12_col1, #T_09574_row12_col2, #T_09574_row12_col3, #T_09574_row12_col4, #T_09574_row12_col5, #T_09574_row12_col6, #T_09574_row12_col7, #T_09574_row13_col0, #T_09574_row13_col1, #T_09574_row13_col2, #T_09574_row13_col3, #T_09574_row13_col4, #T_09574_row13_col5, #T_09574_row13_col6, #T_09574_row13_col7 {
#   text-align: left;
# }
# #T_09574_row0_col1, #T_09574_row0_col2, #T_09574_row0_col3, #T_09574_row0_col4, #T_09574_row0_col5, #T_09574_row0_col6, #T_09574_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_09574_row0_col8, #T_09574_row1_col8, #T_09574_row2_col8, #T_09574_row3_col8, #T_09574_row4_col8, #T_09574_row5_col8, #T_09574_row6_col8, #T_09574_row7_col8, #T_09574_row8_col8, #T_09574_row10_col8, #T_09574_row11_col8, #T_09574_row12_col8, #T_09574_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_09574_row9_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_09574" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09574_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_09574_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_09574_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_09574_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_09574_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_09574_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_09574_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_09574_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_09574_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09574_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_09574_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_09574_row0_col1" class="data row0 col1" >0.9901</td>
#       <td id="T_09574_row0_col2" class="data row0 col2" >0.9996</td>
#       <td id="T_09574_row0_col3" class="data row0 col3" >0.9901</td>
#       <td id="T_09574_row0_col4" class="data row0 col4" >0.9911</td>
#       <td id="T_09574_row0_col5" class="data row0 col5" >0.9900</td>
#       <td id="T_09574_row0_col6" class="data row0 col6" >0.9785</td>
#       <td id="T_09574_row0_col7" class="data row0 col7" >0.9787</td>
#       <td id="T_09574_row0_col8" class="data row0 col8" >1.0710</td>
#     </tr>
#     <tr>
#       <th id="T_09574_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_09574_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_09574_row1_col1" class="data row1 col1" >0.9810</td>
#       <td id="T_09574_row1_col2" class="data row1 col2" >0.9986</td>
#       <td id="T_09574_row1_col3" class="data row1 col3" >0.9810</td>
#       <td id="T_09574_row1_col4" class="data row1 col4" >0.9827</td>
#       <td id="T_09574_row1_col5" class="data row1 col5" >0.9811</td>
#       <td id="T_09574_row1_col6" class="data row1 col6" >0.9588</td>
#       <td id="T_09574_row1_col7" class="data row1 col7" >0.9591</td>
#       <td id="T_09574_row1_col8" class="data row1 col8" >1.9380</td>
#     </tr>
#     <tr>
#       <th id="T_09574_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_09574_row2_col0" class="data row2 col0" >Decision Tree Classifier</td>
#       <td id="T_09574_row2_col1" class="data row2 col1" >0.9653</td>
#       <td id="T_09574_row2_col2" class="data row2 col2" >0.9680</td>
#       <td id="T_09574_row2_col3" class="data row2 col3" >0.9653</td>
#       <td id="T_09574_row2_col4" class="data row2 col4" >0.9670</td>
#       <td id="T_09574_row2_col5" class="data row2 col5" >0.9651</td>
#       <td id="T_09574_row2_col6" class="data row2 col6" >0.9239</td>
#       <td id="T_09574_row2_col7" class="data row2 col7" >0.9244</td>
#       <td id="T_09574_row2_col8" class="data row2 col8" >0.4280</td>
#     </tr>
#     <tr>
#       <th id="T_09574_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_09574_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_09574_row3_col1" class="data row3 col1" >0.9644</td>
#       <td id="T_09574_row3_col2" class="data row3 col2" >0.9976</td>
#       <td id="T_09574_row3_col3" class="data row3 col3" >0.9644</td>
#       <td id="T_09574_row3_col4" class="data row3 col4" >0.9667</td>
#       <td id="T_09574_row3_col5" class="data row3 col5" >0.9640</td>
#       <td id="T_09574_row3_col6" class="data row3 col6" >0.9229</td>
#       <td id="T_09574_row3_col7" class="data row3 col7" >0.9237</td>
#       <td id="T_09574_row3_col8" class="data row3 col8" >0.9840</td>
#     </tr>
#     <tr>
#       <th id="T_09574_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_09574_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_09574_row4_col1" class="data row4 col1" >0.9545</td>
#       <td id="T_09574_row4_col2" class="data row4 col2" >0.9959</td>
#       <td id="T_09574_row4_col3" class="data row4 col3" >0.9545</td>
#       <td id="T_09574_row4_col4" class="data row4 col4" >0.9571</td>
#       <td id="T_09574_row4_col5" class="data row4 col5" >0.9525</td>
#       <td id="T_09574_row4_col6" class="data row4 col6" >0.9013</td>
#       <td id="T_09574_row4_col7" class="data row4 col7" >0.9025</td>
#       <td id="T_09574_row4_col8" class="data row4 col8" >1.1050</td>
#     </tr>
#     <tr>
#       <th id="T_09574_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_09574_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_09574_row5_col1" class="data row5 col1" >0.9156</td>
#       <td id="T_09574_row5_col2" class="data row5 col2" >0.9890</td>
#       <td id="T_09574_row5_col3" class="data row5 col3" >0.9156</td>
#       <td id="T_09574_row5_col4" class="data row5 col4" >0.9150</td>
#       <td id="T_09574_row5_col5" class="data row5 col5" >0.9120</td>
#       <td id="T_09574_row5_col6" class="data row5 col6" >0.8154</td>
#       <td id="T_09574_row5_col7" class="data row5 col7
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]

# %%
print(best_model)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=6921, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
pred = predict_model(best_model)

pred.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_d8b52" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8b52_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d8b52_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_d8b52_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_d8b52_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_d8b52_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_d8b52_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_d8b52_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_d8b52_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8b52_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d8b52_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_d8b52_row0_col1" class="data row0 col1" >0.9904</td>
#       <td id="T_d8b52_row0_col2" class="data row0 col2" >0.9999</td>
#       <td id="T_d8b52_row0_col3" class="data row0 col3" >0.9904</td>
#       <td id="T_d8b52_row0_col4" class="data row0 col4" >0.9909</td>
#       <td id="T_d8b52_row0_col5" class="data row0 col5" >0.9905</td>
#       <td id="T_d8b52_row0_col6" class="data row0 col6" >0.9792</td>
#       <td id="T_d8b52_row0_col7" class="data row0 col7" >0.9793</td>
#     </tr>
#   </tbody>
# </table>
#      buying maint doors persons lug_boot safety  dec prediction_label  \
# 143   vhigh  high     3       4    small    low    2            unacc
# 1567    low   med     4       2    small   high    2            unacc
# 1405    low  high     2       2    small   high    2            unacc
# 1081    med   med     2       2    small   high    2            unacc
# 236   vhigh   med     2    more      med    low    2            unacc
#
#       prediction_score
# 143             1.0000
# 1567            0.9998
# 1405            1.0000
# 1081            1.0000
# 236             1.0000

# %%
save_model(best_model, '2nd_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None, include=[],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='...
#                   LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                  colsample_bytree=1.0, importance_type='split',
#                                  learning_rate=0.1, max_depth=-1,
#                                  min_child_samples=20, min_child_weight=0.001,
#                                  min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                  num_leaves=31, objective=None,
#                                  random_state=6921, reg_alpha=0.0,
#                                  reg_lambda=0.0, subsample=1.0,
#                                  subsample_for_bin=200000, subsample_freq=0))],
#           verbose=False),
#  '2nd_pipeline.pkl')
